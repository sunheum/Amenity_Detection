# %%
# !git clone https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 76018, done.
# remote: Counting objects: 100% (480/480), done.
# remote: Compressing objects: 100% (266/266), done.
# remote: Total 76018 (delta 266), reused 403 (delta 211), pack-reused 75538
# Receiving objects: 100% (76018/76018), 589.47 MiB | 24.82 MiB/s, done.
# Resolving deltas: 100% (53905/53905), done.

# %%
# %cd models/research
# Out:
# /content/models/research

# %%
# Compile protos.
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# Install TensorFlow Object Detection API.
# !cp object_detection/packages/tf2/setup.py .

# %%
# !python -m pip install --upgrade pip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.0 MB 4.9 MB/s
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 21.1.3
#     Uninstalling pip-21.1.3:
#       Successfully uninstalled pip-21.1.3
# ...

# %%
# !python -m pip install --use-feature=2020-resolver .

# %%
# !python object_detection/builders/model_builder_tf2_test.py

# %% [markdown]
# # Google Colab mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 경로 설정

# %%
# TFRecord 저장경로:
# /content/drive/MyDrive/Colab Notebooks/amenity_detection/

# oid_v4_label_map_amenity_30_class.pbtxt 파일 경로 : 
# models/research/object_detection/data/ 

# centernet_hourglass104_512x512_amenity_30class.config : 현재 경로

# %%
# From the tensorflow/models/research/ directory
PIPELINE_CONFIG_PATH="centernet_hourglass104_512x512_amenity_30class.config"
#MODEL_DIR="./saved_result_licenseplate"
MODEL_DIR="/content/drive/MyDrive/saved_result_amenity_detection"

# %%
# !python -m pip install tensorflow==2.7.0

# %%
# !python object_detection/model_main_tf2.py \
    --pipeline_config_path={PIPELINE_CONFIG_PATH} \
    --model_dir={MODEL_DIR} \
    --alsologtostderr
# Out:
# 2022-08-09 00:32:49.477031: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0809 00:32:49.480486 140363864262528 mirrored_strategy.py:376] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0809 00:32:49.486125 140363864262528 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0809 00:32:49.486273 140363864262528 config_util.py:552] Maybe overwriting use_bfloat16: False
# ...
